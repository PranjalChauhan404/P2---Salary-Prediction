# %%
import pandas as pd
import numpy as np

df = pd.read_csv("salary_prediction_data.csv")
df.head()
# Out:
#      Education  Experience  Location Job_Title  Age  Gender         Salary
# 0  High School           8     Urban   Manager   63    Male   84620.053665
# 1          PhD          11  Suburban  Director   59    Male  142591.255894
# 2     Bachelor          28  Suburban   Manager   61  Female   97800.255404
# 3  High School          29     Rural  Director   45    Male   96834.671282
# 4          PhD          25     Urban   Analyst   26  Female  132157.786175

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.isnull().sum()
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Education   1000 non-null   object
#  1   Experience  1000 non-null   int64
#  2   Location    1000 non-null   object
#  3   Job_Title   1000 non-null   object
#  4   Age         1000 non-null   int64
#  5   Gender      1000 non-null   object
#  6   Salary      1000 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 54.8+ KB

# %%
df = pd.get_dummies(df, columns=["Education", "Location", "Job_Title"], dtype=int)
df.columns
# Out:
# Index(['Experience', 'Age', 'Gender', 'Salary', 'Education_Bachelor',
#        'Education_High School', 'Education_Master', 'Education_PhD',
#        'Location_Rural', 'Location_Suburban', 'Location_Urban',
#        'Job_Title_Analyst', 'Job_Title_Director', 'Job_Title_Engineer',
#        'Job_Title_Manager'],
#       dtype='object')

# %%
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})
df["Gender"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: Gender, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#    Experience  Age  Gender         Salary  Education_Bachelor  \
# 0           8   63       0   84620.053665                   0
# 1          11   59       0  142591.255894                   0
# 2          28   61       1   97800.255404                   1
# 3          29   45       0   96834.671282                   0
# 4          25   26       1  132157.786175                   0
#
#    Education_High School  Education_Master  Education_PhD  Location_Rural  \
# 0                      1                 0              0               0
# 1                      0                 0              1               0
# 2                      0                 0              0               0
# 3                      1                 0              0               1
# 4                      0                 0              1               0
#
#    Location_Suburban  Location_Urban  Job_Title_Analyst  Job_Title_Director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Experience             1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   int64
#  3   Salary                 1000 non-null   float64
#  4   Education_Bachelor     1000 non-null   int32
#  5   Education_High School  1000 non-null   int32
#  6   Education_Master       1000 non-null   int32
#  7   Education_PhD          1000 non-null   int32
#  8   Location_Rural         1000 non-null   int32
#  9   Location_Suburban      1000 non-null   int32
#  10  Location_Urban         1000 non-null   int32
#  11  Job_Title_Analyst      1000 non-null   int32
#  12  Job_Title_Director     1000 non-null   int32
#  13  Job_Title_Engineer     1000 non-null   int32
#  14  Job_Title_Manager      1000 non-null   int32
# ...

# %%
X = df.drop("Salary", axis=1)
Y = df["Salary"]

X.head()
print(Y.head())
print(X.shape)
print(Y.shape)
# Out:
# 0     84620.053665
# 1    142591.255894
# 2     97800.255404
# 3     96834.671282
# 4    132157.786175
# Name: Salary, dtype: float64
# (1000, 14)
# (1000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (800, 14)
# (200, 14)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y = model.predict(X_test)
print(X_test, y[:5])
# Out:
#      Experience  Age  Gender  Education_Bachelor  Education_High School  \
# 521          13   57       0                   1                      0
# 737           6   59       0                   0                      1
# 740          16   61       1                   0                      0
# 660           5   26       1                   1                      0
# 411          26   27       0                   1                      0
# ..          ...  ...     ...                 ...                    ...
# 408           2   22       1                   1                      0
# 332          27   58       1                   1                      0
# 208          15   54       0                   0                      1
# 613          24   63       0                   0                      0
# 78            5   26       1                   1                      0
#
#      Education_Master  Education_PhD  Location_Rural  Location_Suburban  \
# ...

# %%
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

mse = mean_squared_error(Y_test, y)
rmse = mse ** 0.5
mae = mean_absolute_error(Y_test, y)
r2 = r2_score(Y_test, y)

print("MSE: ",mse)
print("RMSE: ",rmse)
print("MAE: ",mae)
print("R2: ",r2)
# Out:
# MSE:  105996277.66096844
# RMSE:  10295.449366636138
# MAE:  8157.898478643163
# R2:  0.8701863681609705

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="winter", fmt=".2f", linewidths=0.5)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
sns.histplot(df["Salary"])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
plt.figure(figsize=(6, 4))
plt.scatter(Y_test, y, alpha=0.7)
plt.plot(
    [Y_test.min(), Y_test.max()],
    [Y_test.min(), Y_test.max()],
    color="purple",
    linewidth=2
)

plt.xlabel("Actual Salary")
plt.ylabel("Prediction Salary")
plt.title("Actual vs. Predicted Salary")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.regplot(
    x=df["Experience"],
    y=df["Salary"],
    line_kws={"color":"red"}
)

plt.title("Experience vs Salary")
plt.show()
